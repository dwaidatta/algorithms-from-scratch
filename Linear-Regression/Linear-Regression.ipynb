# %% [markdown]
# <center><bold>
#
# ## Linear Regression From Scratch
#
# </bold></center>

# %% [markdown]
# ### Importing the data

# %%
import sklearn
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.datasets import make_regression

# %%
Data = make_regression(n_samples=1000, n_features=1, noise=10, random_state=42, bias=40)
X = Data[0]
Y = Data[1]
X.shape, Y.shape
# Out:
# ((1000, 1), (1000,))

# %%
plt.style.use("seaborn-v0_8-whitegrid")
plt.figure(figsize=(10, 8))
plt.scatter(X, Y, c=Y, cmap=plt.cm.coolwarm, label="Data Points")
plt.axhline(y=0, color='black', linewidth=1)  # X-axis line
plt.axvline(x=0, color='black', linewidth=1)  # Y-axis line
plt.title("Linear Regression", fontsize=16, weight="bold")
plt.xlabel("X axis", fontsize=12, weight="bold")
plt.ylabel("Y axis", fontsize=12, weight="bold")
plt.legend()
plt.grid(linestyle="--", alpha=0.8)
plt.show()

# %% [markdown]
# ### Linear Regression Model Formula
#
# The formula for a linear regression model is:
# <h4>
#
# $$
# y = \beta_0 + \beta_1 x_1 + \beta_2 x_2 + \dots + \beta_n x_n + \epsilon
# $$
#
# </h4>
# Where:
#
# - $\ y$ = predicted output
# - $\beta_0$ = intercept (bias term)
# - $\beta_1, \beta_2, \dots, \beta_n$ = coefficients (weights)
# - $x_1, x_2, \dots, x_n$ = input features
# - $\epsilon$ = error term (residual) (NOT IMPLEMENTED IN THIS MODEL)

# %%
def h(X, W):
    h = W[1] * np.array(X[:, 0]) + W[0]
    return h

# %% [markdown]
# ### Implement Linear Regreassion with Gradient Descent
#
# #### Gradient Descent Update Rule
#
# In gradient descent, the parameters are updated in the direction that reduces the cost function. The update rule is:
# <h4>
#
# $$
# \theta_j := \theta_j - \alpha \frac{\partial J(\theta)}{\partial \theta_j}
# $$
#
# </h4>
#
# Where:
#
# - $\theta_j$ = the $j$-th parameter (e.g., $\beta_j$ in linear regression)
# - $\alpha$ = learning rate (a small positive scalar)
# - $J(\theta)$ = cost function (e.g., Mean Squared Error for linear regression)
# - $\frac{\partial J(\theta)}{\partial \theta_j}$ = partial derivative of the cost function with respect to $\theta_j$

# %%
def h(X, W):
    h = W[1] * np.array(X[:, 0]) + W[0]
    return h

def loss(ypred, Y):
    l = np.mean(np.square(Y - np.array(ypred)))/2
    return l

def gradient(ypred, X):
    g = [0] * 2
    g[0] = np.mean((np.array(ypred) - Y))
    g[1] = np.mean((np.array(ypred) - Y) * X[:, 0])
    return g

def gradient_descent(X, Y, lr=0.01, epoch_limit=1000):
    W = [0, 0]
    losses = []
    j = 0
    while True:
        ypred = h(X, W)
        loss_value = loss(ypred, Y)
        g = gradient(ypred, X)
        W[0] = W[0] - lr * g[0]
        W[1] = W[1] - lr * g[1]
        losses.append(loss_value)
        print(f"Loss : {loss_value:.2f}, Weights : {W[0]:.2f}, {W[1]:.2f}, Epoch : {j}")
        j = j + 1
        if(j>epoch_limit):
            return W, losses

epochs = 1000
W_new, losses = gradient_descent(X, Y, epoch_limit=epochs)
W_new
# Out:
# Loss : 996.26, Weights : 0.40, 0.17, Epoch : 0
# Loss : 977.27, Weights : 0.80, 0.33, Epoch : 1
# Loss : 958.66, Weights : 1.20, 0.50, Epoch : 2
# Loss : 940.42, Weights : 1.59, 0.66, Epoch : 3
# Loss : 922.55, Weights : 1.98, 0.82, Epoch : 4
# Loss : 905.03, Weights : 2.36, 0.98, Epoch : 5
# Loss : 887.87, Weights : 2.74, 1.14, Epoch : 6
# Loss : 871.05, Weights : 3.12, 1.29, Epoch : 7
# Loss : 854.57, Weights : 3.49, 1.45, Epoch : 8
# Loss : 838.42, Weights : 3.86, 1.60, Epoch : 9
# Loss : 822.59, Weights : 4.22, 1.75, Epoch : 10
# Loss : 807.08, Weights : 4.58, 1.90, Epoch : 11
# Loss : 791.88, Weights : 4.94, 2.05, Epoch : 12
# Loss : 776.99, Weights : 5.30, 2.19, Epoch : 13
# Loss : 762.39, Weights : 5.65, 2.34, Epoch : 14
# Loss : 748.09, Weights : 5.99, 2.48, Epoch : 15
# Loss : 734.07, Weights : 6.34, 2.62, Epoch : 16
# Loss : 720.34, Weights : 6.68, 2.76, Epoch : 17
# Loss : 706.88, Weights : 7.01, 2.90, Epoch : 18
# Loss : 693.69, Weights : 7.35, 3.04, Epoch : 19
# Loss : 680.76, Weights : 7.67, 3.18, Epoch : 20
# Loss : 668.10, Weights : 8.00, 3.31, Epoch : 21
# Loss : 655.68, Weights : 8.32, 3.45, Epoch : 22
# Loss : 643.52, Weights : 8.64, 3.58, Epoch : 23
# Loss : 631.60, Weights : 8.96, 3.71, Epoch : 24
# Loss : 619.92, Weights : 9.27, 3.84, Epoch : 25
# Loss : 608.47, Weights : 9.58, 3.97, Epoch : 26
# Loss : 597.26, Weights : 9.89, 4.10, Epoch : 27
# Loss : 586.26, Weights : 10.19, 4.22, Epoch : 28
# Loss : 575.49, Weights : 10.50, 4.35, Epoch : 29
# Loss : 564.94, Weights : 10.79, 4.47, Epoch : 30
# Loss : 554.59, Weights : 11.09, 4.59, Epoch : 31
# Loss : 544.46, Weights : 11.38, 4.71, Epoch : 32
# Loss : 534.52, Weights : 11.67, 4.83, Epoch : 33
# Loss : 524.79, Weights : 11.96, 4.95, Epoch : 34
# Loss : 515.25, Weights : 12.24, 5.07, Epoch : 35
# Loss : 505.90, Weights : 12.52, 5.19, Epoch : 36
# Loss : 496.74, Weights : 12.80, 5.30, Epoch : 37
# Loss : 487.76, Weights : 13.07, 5.41, Epoch : 38
# Loss : 478.97, Weights : 13.34, 5.53, Epoch : 39
# Loss : 470.35, Weights : 13.61, 5.64, Epoch : 40
# Loss : 461.90, Weights : 13.88, 5.75, Epoch : 41
# Loss : 453.62, Weights : 14.14, 5.86, Epoch : 42
# Loss : 445.51, Weights : 14.40, 5.97, Epoch : 43
# Loss : 437.56, Weights : 14.66, 6.07, Epoch : 44
# Loss : 429.77, Weights : 14.92, 6.18, Epoch : 45
# Loss : 422.13, Weights : 15.17, 6.29, Epoch : 46
# Loss : 414.65, Weights : 15.42, 6.39, Epoch : 47
# Loss : 407.32, Weights : 15.67, 6.49, Epoch : 48
# Loss : 400.14, Weights : 15.92, 6.59, Epoch : 49
# Loss : 393.10, Weights : 16.16, 6.70, Epoch : 50
# Loss : 386.20, Weights : 16.40, 6.80, Epoch : 51
# Loss : 379.44, Weights : 16.64, 6.89, Epoch : 52
# Loss : 372.81, Weights : 16.87, 6.99, Epoch : 53
# Loss : 366.32, Weights : 17.11, 7.09, Epoch : 54
# Loss : 359.96, Weights : 17.34, 7.18, Epoch : 55
# Loss : 353.72, Weights : 17.57, 7.28, Epoch : 56
# Loss : 347.62, Weights : 17.79, 7.37, Epoch : 57
# Loss : 341.63, Weights : 18.02, 7.47, Epoch : 58
# Loss : 335.76, Weights : 18.24, 7.56, Epoch : 59
# Loss : 330.01, Weights : 18.46, 7.65, Epoch : 60
# Loss : 324.38, Weights : 18.68, 7.74, Epoch : 61
# Loss : 318.86, Weights : 18.89, 7.83, Epoch : 62
# Loss : 313.45, Weights : 19.11, 7.92, Epoch : 63
# Loss : 308.14, Weights : 19.32, 8.01, Epoch : 64
# Loss : 302.95, Weights : 19.53, 8.09, Epoch : 65
# Loss : 297.86, Weights : 19.73, 8.18, Epoch : 66
# Loss : 292.87, Weights : 19.94, 8.26, Epoch : 67
# Loss : 287.98, Weights : 20.14, 8.35, Epoch : 68
# Loss : 283.19, Weights : 20.34, 8.43, Epoch : 69
# Loss : 278.49, Weights : 20.54, 8.51, Epoch : 70
# Loss : 273.89, Weights : 20.74, 8.59, Epoch : 71
# Loss : 269.38, Weights : 20.93, 8.68, Epoch : 72
# Loss : 264.96, Weights : 21.12, 8.76, Epoch : 73
# Loss : 260.63, Weights : 21.31, 8.83, Epoch : 74
# Loss : 256.39, Weights : 21.50, 8.91, Epoch : 75
# Loss : 252.23, Weights : 21.69, 8.99, Epoch : 76
# Loss : 248.16, Weights : 21.88, 9.07, Epoch : 77
# Loss : 244.17, Weights : 22.06, 9.14, Epoch : 78
# Loss : 240.25, Weights : 22.24, 9.22, Epoch : 79
# Loss : 236.42, Weights : 22.42, 9.29, Epoch : 80
# Loss : 232.66, Weights : 22.60, 9.37, Epoch : 81
# Loss : 228.98, Weights : 22.77, 9.44, Epoch : 82
# Loss : 225.37, Weights : 22.95, 9.51, Epoch : 83
# Loss : 221.84, Weights : 23.12, 9.58, Epoch : 84
# Loss : 218.37, Weights : 23.29, 9.65, Epoch : 85
# Loss : 214.97, Weights : 23.46, 9.72, Epoch : 86
# Loss : 211.65, Weights : 23.63, 9.79, Epoch : 87
# Loss : 208.39, Weights : 23.79, 9.86, Epoch : 88
# Loss : 205.19, Weights : 23.96, 9.93, Epoch : 89
# Loss : 202.06, Weights : 24.12, 10.00, Epoch : 90
# Loss : 198.99, Weights : 24.28, 10.06, Epoch : 91
# Loss : 195.98, Weights : 24.44, 10.13, Epoch : 92
# Loss : 193.04, Weights : 24.59, 10.20, Epoch : 93
# Loss : 190.15, Weights : 24.75, 10.26, Epoch : 94
# Loss : 187.32, Weights : 24.90, 10.32, Epoch : 95
# Loss : 184.55, Weights : 25.06, 10.39, Epoch : 96
# Loss : 181.83, Weights : 25.21, 10.45, Epoch : 97
# Loss : 179.17, Weights : 25.36, 10.51, Epoch : 98
# Loss : 176.56, Weights : 25.51, 10.57, Epoch : 99
# Loss : 174.00, Weights : 25.65, 10.64, Epoch : 100
# Loss : 171.49, Weights : 25.80, 10.70, Epoch : 101
# Loss : 169.04, Weights : 25.94, 10.76, Epoch : 102
# Loss : 166.63, Weights : 26.08, 10.81, Epoch : 103
# Loss : 164.27, Weights : 26.22, 10.87, Epoch : 104
# Loss : 161.96, Weights : 26.36, 10.93, Epoch : 105
# Loss : 159.70, Weights : 26.50, 10.99, Epoch : 106
# Loss : 157.48, Weights : 26.64, 11.04, Epoch : 107
# Loss : 155.30, Weights : 26.77, 11.10, Epoch : 108
# Loss : 153.17, Weights : 26.91, 11.16, Epoch : 109
# Loss : 151.08, Weights : 27.04, 11.21, Epoch : 110
# Loss : 149.04, Weights : 27.17, 11.27, Epoch : 111
# Loss : 147.03, Weights : 27.30, 11.32, Epoch : 112
# Loss : 145.07, Weights : 27.43, 11.37, Epoch : 113
# Loss : 143.14, Weights : 27.56, 11.43, Epoch : 114
# Loss : 141.25, Weights : 27.68, 11.48, Epoch : 115
# Loss : 139.40, Weights : 27.81, 11.53, Epoch : 116
# Loss : 137.59, Weights : 27.93, 11.58, Epoch : 117
# Loss : 135.81, Weights : 28.05, 11.63, Epoch : 118
# Loss : 134.07, Weights : 28.17, 11.68, Epoch : 119
# Loss : 132.37, Weights : 28.29, 11.73, Epoch : 120
# Loss : 130.70, Weights : 28.41, 11.78, Epoch : 121
# Loss : 129.06, Weights : 28.53, 11.83, Epoch : 122
# Loss : 127.45, Weights : 28.64, 11.88, Epoch : 123
# Loss : 125.88, Weights : 28.76, 11.93, Epoch : 124
# Loss : 124.34, Weights : 28.87, 11.97, Epoch : 125
# Loss : 122.83, Weights : 28.99, 12.02, Epoch : 126
# Loss : 121.35, Weights : 29.10, 12.07, Epoch : 127
# Loss : 119.90, Weights : 29.21, 12.11, Epoch : 128
# Loss : 118.48, Weights : 29.32, 12.16, Epoch : 129
# Loss : 117.09, Weights : 29.42, 12.20, Epoch : 130
# Loss : 115.72, Weights : 29.53, 12.25, Epoch : 131
# Loss : 114.38, Weights : 29.64, 12.29, Epoch : 132
# Loss : 113.07, Weights : 29.74, 12.33, Epoch : 133
# Loss : 111.79, Weights : 29.85, 12.38, Epoch : 134
# Loss : 110.53, Weights : 29.95, 12.42, Epoch : 135
# Loss : 109.30, Weights : 30.05, 12.46, Epoch : 136
# Loss : 108.09, Weights : 30.15, 12.51, Epoch : 137
# Loss : 106.90, Weights : 30.25, 12.55, Epoch : 138
# Loss : 105.74, Weights : 30.35, 12.59, Epoch : 139
# Loss : 104.60, Weights : 30.45, 12.63, Epoch : 140
# Loss : 103.49, Weights : 30.55, 12.67, Epoch : 141
# Loss : 102.40, Weights : 30.64, 12.71, Epoch : 142
# Loss : 101.33, Weights : 30.74, 12.75, Epoch : 143
# Loss : 100.28, Weights : 30.83, 12.79, Epoch : 144
# Loss : 99.25, Weights : 30.92, 12.83, Epoch : 145
# Loss : 98.24, Weights : 31.01, 12.86, Epoch : 146
# Loss : 97.26, Weights : 31.11, 12.90, Epoch : 147
# Loss : 96.29, Weights : 31.20, 12.94, Epoch : 148
# Loss : 95.34, Weights : 31.28, 12.98, Epoch : 149
# Loss : 94.41, Weights : 31.37, 13.01, Epoch : 150
# Loss : 93.50, Weights : 31.46, 13.05, Epoch : 151
# Loss : 92.61, Weights : 31.55, 13.09, Epoch : 152
# Loss : 91.73, Weights : 31.63, 13.12, Epoch : 153
# Loss : 90.88, Weights : 31.72, 13.16, Epoch : 154
# Loss : 90.04, Weights : 31.80, 13.19, Epoch : 155
# Loss : 89.22, Weights : 31.88, 13.23, Epoch : 156
# Loss : 88.41, Weights : 31.97, 13.26, Epoch : 157
# Loss : 87.62, Weights : 32.05, 13.29, Epoch : 158
# Loss : 86.85, Weights : 32.13, 13.33, Epoch : 159
# Loss : 86.09, Weights : 32.21, 13.36, Epoch : 160
# Loss : 85.34, Weights : 32.29, 13.39, Epoch : 161
# Loss : 84.62, Weights : 32.37, 13.43, Epoch : 162
# Loss : 83.90, Weights : 32.44, 13.46, Epoch : 163
# Loss : 83.20, Weights : 32.52, 13.49, Epoch : 164
# Loss : 82.52, Weights : 32.60, 13.52, Epoch : 165
# Loss : 81.84, Weights : 32.67, 13.55, Epoch : 166
# Loss : 81.19, Weights : 32.75, 13.58, Epoch : 167
# Loss : 80.54, Weights : 32.82, 13.61, Epoch : 168
# Loss : 79.91, Weights : 32.89, 13.64, Epoch : 169
# Loss : 79.29, Weights : 32.96, 13.67, Epoch : 170
# Loss : 78.68, Weights : 33.04, 13.70, Epoch : 171
# Loss : 78.09, Weights : 33.11, 13.73, Epoch : 172
# Loss : 77.50, Weights : 33.18, 13.76, Epoch : 173
# Loss : 76.93, Weights : 33.24, 13.79, Epoch : 174
# Loss : 76.37, Weights : 33.31, 13.82, Epoch : 175
# Loss : 75.82, Weights : 33.38, 13.85, Epoch : 176
# Loss : 75.29, Weights : 33.45, 13.88, Epoch : 177
# Loss : 74.76, Weights : 33.52, 13.90, Epoch : 178
# Loss : 74.24, Weights : 33.58, 13.93, Epoch : 179
# Loss : 73.74, Weights : 33.65, 13.96, Epoch : 180
# Loss : 73.24, Weights : 33.71, 13.99, Epoch : 181
# Loss : 72.76, Weights : 33.77, 14.01, Epoch : 182
# Loss : 72.28, Weights : 33.84, 14.04, Epoch : 183
# Loss : 71.81, Weights : 33.90, 14.06, Epoch : 184
# Loss : 71.36, Weights : 33.96, 14.09, Epoch : 185
# Loss : 70.91, Weights : 34.02, 14.12, Epoch : 186
# Loss : 70.47, Weights : 34.08, 14.14, Epoch : 187
# Loss : 70.04, Weights : 34.14, 14.17, Epoch : 188
# Loss : 69.62, Weights : 34.20, 14.19, Epoch : 189
# Loss : 69.20, Weights : 34.26, 14.22, Epoch : 190
# Loss : 68.80, Weights : 34.32, 14.24, Epoch : 191
# Loss : 68.40, Weights : 34.38, 14.26, Epoch : 192
# Loss : 68.01, Weights : 34.44, 14.29, Epoch : 193
# Loss : 67.63, Weights : 34.49, 14.31, Epoch : 194
# Loss : 67.26, Weights : 34.55, 14.33, Epoch : 195
# Loss : 66.89, Weights : 34.60, 14.36, Epoch : 196
# Loss : 66.53, Weights : 34.66, 14.38, Epoch : 197
# Loss : 66.18, Weights : 34.71, 14.40, Epoch : 198
# Loss : 65.84, Weights : 34.77, 14.43, Epoch : 199
# Loss : 65.50, Weights : 34.82, 14.45, Epoch : 200
# Loss : 65.17, Weights : 34.87, 14.47, Epoch : 201
# Loss : 64.85, Weights : 34.92, 14.49, Epoch : 202
# Loss : 64.53, Weights : 34.98, 14.51, Epoch : 203
# Loss : 64.22, Weights : 35.03, 14.53, Epoch : 204
# Loss : 63.91, Weights : 35.08, 14.56, Epoch : 205
# Loss : 63.61, Weights : 35.13, 14.58, Epoch : 206
# Loss : 63.32, Weights : 35.18, 14.60, Epoch : 207
# Loss : 63.03, Weights : 35.23, 14.62, Epoch : 208
# Loss : 62.75, Weights : 35.28, 14.64, Epoch : 209
# Loss : 62.48, Weights : 35.32, 14.66, Epoch : 210
# Loss : 62.21, Weights : 35.37, 14.68, Epoch : 211
# Loss : 61.94, Weights : 35.42, 14.70, Epoch : 212
# Loss : 61.68, Weights : 35.46, 14.72, Epoch : 213
# Loss : 61.43, Weights : 35.51, 14.74, Epoch : 214
# Loss : 61.18, Weights : 35.56, 14.76, Epoch : 215
# Loss : 60.94, Weights : 35.60, 14.77, Epoch : 216
# Loss : 60.70, Weights : 35.65, 14.79, Epoch : 217
# Loss : 60.46, Weights : 35.69, 14.81, Epoch : 218
# Loss : 60.23, Weights : 35.73, 14.83, Epoch : 219
# Loss : 60.01, Weights : 35.78, 14.85, Epoch : 220
# Loss : 59.79, Weights : 35.82, 14.87, Epoch : 221
# Loss : 59.57, Weights : 35.86, 14.88, Epoch : 222
# Loss : 59.36, Weights : 35.91, 14.90, Epoch : 223
# Loss : 59.15, Weights : 35.95, 14.92, Epoch : 224
# Loss : 58.95, Weights : 35.99, 14.94, Epoch : 225
# Loss : 58.75, Weights : 36.03, 14.95, Epoch : 226
# Loss : 58.55, Weights : 36.07, 14.97, Epoch : 227
# Loss : 58.36, Weights : 36.11, 14.99, Epoch : 228
# Loss : 58.18, Weights : 36.15, 15.00, Epoch : 229
# Loss : 57.99, Weights : 36.19, 15.02, Epoch : 230
# Loss : 57.81, Weights : 36.23, 15.04, Epoch : 231
# Loss : 57.64, Weights : 36.27, 15.05, Epoch : 232
# Loss : 57.46, Weights : 36.30, 15.07, Epoch : 233
# Loss : 57.29, Weights : 36.34, 15.08, Epoch : 234
# Loss : 57.13, Weights : 36.38, 15.10, Epoch : 235
# Loss : 56.96, Weights : 36.42, 15.11, Epoch : 236
# Loss : 56.80, Weights : 36.45, 15.13, Epoch : 237
# Loss : 56.65, Weights : 36.49, 15.14, Epoch : 238
# Loss : 56.49, Weights : 36.53, 15.16, Epoch : 239
# Loss : 56.34, Weights : 36.56, 15.17, Epoch : 240
# Loss : 56.20, Weights : 36.60, 15.19, Epoch : 241
# Loss : 56.05, Weights : 36.63, 15.20, Epoch : 242
# Loss : 55.91, Weights : 36.67, 15.22, Epoch : 243
# Loss : 55.77, Weights : 36.70, 15.23, Epoch : 244
# Loss : 55.64, Weights : 36.73, 15.25, Epoch : 245
# Loss : 55.51, Weights : 36.77, 15.26, Epoch : 246
# Loss : 55.38, Weights : 36.80, 15.27, Epoch : 247
# Loss : 55.25, Weights : 36.83, 15.29, Epoch : 248
# Loss : 55.12, Weights : 36.86, 15.30, Epoch : 249
# Loss : 55.00, Weights : 36.90, 15.31, Epoch : 250
# Loss : 54.88, Weights : 36.93, 15.33, Epoch : 251
# Loss : 54.76, Weights : 36.96, 15.34, Epoch : 252
# Loss : 54.65, Weights : 36.99, 15.35, Epoch : 253
# Loss : 54.53, Weights : 37.02, 15.37, Epoch : 254
# Loss : 54.42, Weights : 37.05, 15.38, Epoch : 255
# Loss : 54.31, Weights : 37.08, 15.39, Epoch : 256
# Loss : 54.21, Weights : 37.11, 15.40, Epoch : 257
# Loss : 54.10, Weights : 37.14, 15.42, Epoch : 258
# Loss : 54.00, Weights : 37.17, 15.43, Epoch : 259
# Loss : 53.90, Weights : 37.20, 15.44, Epoch : 260
# Loss : 53.80, Weights : 37.23, 15.45, Epoch : 261
# Loss : 53.71, Weights : 37.26, 15.46, Epoch : 262
# Loss : 53.61, Weights : 37.29, 15.48, Epoch : 263
# Loss : 53.52, Weights : 37.31, 15.49, Epoch : 264
# Loss : 53.43, Weights : 37.34, 15.50, Epoch : 265
# Loss : 53.34, Weights : 37.37, 15.51, Epoch : 266
# Loss : 53.25, Weights : 37.39, 15.52, Epoch : 267
# Loss : 53.17, Weights : 37.42, 15.53, Epoch : 268
# Loss : 53.09, Weights : 37.45, 15.54, Epoch : 269
# Loss : 53.00, Weights : 37.47, 15.56, Epoch : 270
# Loss : 52.92, Weights : 37.50, 15.57, Epoch : 271
# Loss : 52.85, Weights : 37.53, 15.58, Epoch : 272
# Loss : 52.77, Weights : 37.55, 15.59, Epoch : 273
# Loss : 52.69, Weights : 37.58, 15.60, Epoch : 274
# Loss : 52.62, Weights : 37.60, 15.61, Epoch : 275
# Loss : 52.55, Weights : 37.63, 15.62, Epoch : 276
# Loss : 52.48, Weights : 37.65, 15.63, Epoch : 277
# Loss : 52.41, Weights : 37.67, 15.64, Epoch : 278
# Loss : 52.34, Weights : 37.70, 15.65, Epoch : 279
# Loss : 52.27, Weights : 37.72, 15.66, Epoch : 280
# Loss : 52.21, Weights : 37.75, 15.67, Epoch : 281
# Loss : 52.14, Weights : 37.77, 15.68, Epoch : 282
# Loss : 52.08, Weights : 37.79, 15.69, Epoch : 283
# Loss : 52.02, Weights : 37.81, 15.70, Epoch : 284
# Loss : 51.96, Weights : 37.84, 15.71, Epoch : 285
# Loss : 51.90, Weights : 37.86, 15.72, Epoch : 286
# Loss : 51.84, Weights : 37.88, 15.73, Epoch : 287
# Loss : 51.78, Weights : 37.90, 15.73, Epoch : 288
# Loss : 51.73, Weights : 37.92, 15.74, Epoch : 289
# Loss : 51.67, Weights : 37.95, 15.75, Epoch : 290
# Loss : 51.62, Weights : 37.97, 15.76, Epoch : 291
# Loss : 51.57, Weights : 37.99, 15.77, Epoch : 292
# Loss : 51.52, Weights : 38.01, 15.78, Epoch : 293
# Loss : 51.47, Weights : 38.03, 15.79, Epoch : 294
# Loss : 51.42, Weights : 38.05, 15.80, Epoch : 295
# Loss : 51.37, Weights : 38.07, 15.80, Epoch : 296
# Loss : 51.32, Weights : 38.09, 15.81, Epoch : 297
# Loss : 51.28, Weights : 38.11, 15.82, Epoch : 298
# Loss : 51.23, Weights : 38.13, 15.83, Epoch : 299
# Loss : 51.19, Weights : 38.15, 15.84, Epoch : 300
# Loss : 51.14, Weights : 38.17, 15.85, Epoch : 301
# Loss : 51.10, Weights : 38.19, 15.85, Epoch : 302
# Loss : 51.06, Weights : 38.20, 15.86, Epoch : 303
# Loss : 51.02, Weights : 38.22, 15.87, Epoch : 304
# Loss : 50.98, Weights : 38.24, 15.88, Epoch : 305
# Loss : 50.94, Weights : 38.26, 15.88, Epoch : 306
# Loss : 50.90, Weights : 38.28, 15.89, Epoch : 307
# Loss : 50.86, Weights : 38.30, 15.90, Epoch : 308
# Loss : 50.82, Weights : 38.31, 15.91, Epoch : 309
# Loss : 50.79, Weights : 38.33, 15.91, Epoch : 310
# Loss : 50.75, Weights : 38.35, 15.92, Epoch : 311
# Loss : 50.72, Weights : 38.37, 15.93, Epoch : 312
# Loss : 50.68, Weights : 38.38, 15.94, Epoch : 313
# Loss : 50.65, Weights : 38.40, 15.94, Epoch : 314
# Loss : 50.62, Weights : 38.42, 15.95, Epoch : 315
# Loss : 50.58, Weights : 38.43, 15.96, Epoch : 316
# Loss : 50.55, Weights : 38.45, 15.96, Epoch : 317
# Loss : 50.52, Weights : 38.46, 15.97, Epoch : 318
# Loss : 50.49, Weights : 38.48, 15.98, Epoch : 319
# Loss : 50.46, Weights : 38.50, 15.98, Epoch : 320
# Loss : 50.43, Weights : 38.51, 15.99, Epoch : 321
# Loss : 50.40, Weights : 38.53, 16.00, Epoch : 322
# Loss : 50.37, Weights : 38.54, 16.00, Epoch : 323
# Loss : 50.35, Weights : 38.56, 16.01, Epoch : 324
# Loss : 50.32, Weights : 38.57, 16.01, Epoch : 325
# Loss : 50.29, Weights : 38.59, 16.02, Epoch : 326
# Loss : 50.27, Weights : 38.60, 16.03, Epoch : 327
# Loss : 50.24, Weights : 38.62, 16.03, Epoch : 328
# Loss : 50.22, Weights : 38.63, 16.04, Epoch : 329
# Loss : 50.19, Weights : 38.65, 16.05, Epoch : 330
# Loss : 50.17, Weights : 38.66, 16.05, Epoch : 331
# Loss : 50.15, Weights : 38.67, 16.06, Epoch : 332
# Loss : 50.12, Weights : 38.69, 16.06, Epoch : 333
# Loss : 50.10, Weights : 38.70, 16.07, Epoch : 334
# Loss : 50.08, Weights : 38.71, 16.07, Epoch : 335
# Loss : 50.06, Weights : 38.73, 16.08, Epoch : 336
# Loss : 50.04, Weights : 38.74, 16.09, Epoch : 337
# Loss : 50.02, Weights : 38.75, 16.09, Epoch : 338
# Loss : 50.00, Weights : 38.77, 16.10, Epoch : 339
# Loss : 49.98, Weights : 38.78, 16.10, Epoch : 340
# Loss : 49.96, Weights : 38.79, 16.11, Epoch : 341
# Loss : 49.94, Weights : 38.81, 16.11, Epoch : 342
# Loss : 49.92, Weights : 38.82, 16.12, Epoch : 343
# Loss : 49.90, Weights : 38.83, 16.12, Epoch : 344
# Loss : 49.88, Weights : 38.84, 16.13, Epoch : 345
# Loss : 49.87, Weights : 38.85, 16.13, Epoch : 346
# Loss : 49.85, Weights : 38.87, 16.14, Epoch : 347
# Loss : 49.83, Weights : 38.88, 16.14, Epoch : 348
# Loss : 49.82, Weights : 38.89, 16.15, Epoch : 349
# Loss : 49.80, Weights : 38.90, 16.15, Epoch : 350
# Loss : 49.78, Weights : 38.91, 16.16, Epoch : 351
# Loss : 49.77, Weights : 38.93, 16.16, Epoch : 352
# Loss : 49.75, Weights : 38.94, 16.17, Epoch : 353
# Loss : 49.74, Weights : 38.95, 16.17, Epoch : 354
# Loss : 49.72, Weights : 38.96, 16.18, Epoch : 355
# Loss : 49.71, Weights : 38.97, 16.18, Epoch : 356
# Loss : 49.70, Weights : 38.98, 16.19, Epoch : 357
# Loss : 49.68, Weights : 38.99, 16.19, Epoch : 358
# Loss : 49.67, Weights : 39.00, 16.19, Epoch : 359
# Loss : 49.65, Weights : 39.01, 16.20, Epoch : 360
# Loss : 49.64, Weights : 39.02, 16.20, Epoch : 361
# Loss : 49.63, Weights : 39.03, 16.21, Epoch : 362
# Loss : 49.62, Weights : 39.04, 16.21, Epoch : 363
# Loss : 49.60, Weights : 39.05, 16.22, Epoch : 364
# Loss : 49.59, Weights : 39.06, 16.22, Epoch : 365
# Loss : 49.58, Weights : 39.07, 16.22, Epoch : 366
# Loss : 49.57, Weights : 39.08, 16.23, Epoch : 367
# Loss : 49.56, Weights : 39.09, 16.23, Epoch : 368
# Loss : 49.55, Weights : 39.10, 16.24, Epoch : 369
# Loss : 49.54, Weights : 39.11, 16.24, Epoch : 370
# Loss : 49.53, Weights : 39.12, 16.24, Epoch : 371
# Loss : 49.52, Weights : 39.13, 16.25, Epoch : 372
# Loss : 49.51, Weights : 39.14, 16.25, Epoch : 373
# Loss : 49.50, Weights : 39.15, 16.26, Epoch : 374
# Loss : 49.49, Weights : 39.16, 16.26, Epoch : 375
# Loss : 49.48, Weights : 39.17, 16.26, Epoch : 376
# Loss : 49.47, Weights : 39.18, 16.27, Epoch : 377
# Loss : 49.46, Weights : 39.18, 16.27, Epoch : 378
# Loss : 49.45, Weights : 39.19, 16.27, Epoch : 379
# Loss : 49.44, Weights : 39.20, 16.28, Epoch : 380
# Loss : 49.43, Weights : 39.21, 16.28, Epoch : 381
# Loss : 49.42, Weights : 39.22, 16.29, Epoch : 382
# Loss : 49.41, Weights : 39.23, 16.29, Epoch : 383
# Loss : 49.41, Weights : 39.24, 16.29, Epoch : 384
# Loss : 49.40, Weights : 39.24, 16.30, Epoch : 385
# Loss : 49.39, Weights : 39.25, 16.30, Epoch : 386
# Loss : 49.38, Weights : 39.26, 16.30, Epoch : 387
# Loss : 49.38, Weights : 39.27, 16.31, Epoch : 388
# Loss : 49.37, Weights : 39.28, 16.31, Epoch : 389
# Loss : 49.36, Weights : 39.28, 16.31, Epoch : 390
# Loss : 49.35, Weights : 39.29, 16.32, Epoch : 391
# Loss : 49.35, Weights : 39.30, 16.32, Epoch : 392
# Loss : 49.34, Weights : 39.31, 16.32, Epoch : 393
# Loss : 49.33, Weights : 39.31, 16.33, Epoch : 394
# Loss : 49.33, Weights : 39.32, 16.33, Epoch : 395
# Loss : 49.32, Weights : 39.33, 16.33, Epoch : 396
# Loss : 49.31, Weights : 39.34, 16.33, Epoch : 397
# Loss : 49.31, Weights : 39.34, 16.34, Epoch : 398
# Loss : 49.30, Weights : 39.35, 16.34, Epoch : 399
# Loss : 49.30, Weights : 39.36, 16.34, Epoch : 400
# Loss : 49.29, Weights : 39.36, 16.35, Epoch : 401
# Loss : 49.28, Weights : 39.37, 16.35, Epoch : 402
# Loss : 49.28, Weights : 39.38, 16.35, Epoch : 403
# Loss : 49.27, Weights : 39.38, 16.35, Epoch : 404
# Loss : 49.27, Weights : 39.39, 16.36, Epoch : 405
# Loss : 49.26, Weights : 39.40, 16.36, Epoch : 406
# Loss : 49.26, Weights : 39.40, 16.36, Epoch : 407
# Loss : 49.25, Weights : 39.41, 16.37, Epoch : 408
# Loss : 49.25, Weights : 39.42, 16.37, Epoch : 409
# Loss : 49.24, Weights : 39.42, 16.37, Epoch : 410
# Loss : 49.24, Weights : 39.43, 16.37, Epoch : 411
# Loss : 49.23, Weights : 39.44, 16.38, Epoch : 412
# Loss : 49.23, Weights : 39.44, 16.38, Epoch : 413
# Loss : 49.23, Weights : 39.45, 16.38, Epoch : 414
# Loss : 49.22, Weights : 39.45, 16.38, Epoch : 415
# Loss : 49.22, Weights : 39.46, 16.39, Epoch : 416
# Loss : 49.21, Weights : 39.47, 16.39, Epoch : 417
# Loss : 49.21, Weights : 39.47, 16.39, Epoch : 418
# Loss : 49.20, Weights : 39.48, 16.39, Epoch : 419
# Loss : 49.20, Weights : 39.48, 16.40, Epoch : 420
# Loss : 49.20, Weights : 39.49, 16.40, Epoch : 421
# Loss : 49.19, Weights : 39.49, 16.40, Epoch : 422
# Loss : 49.19, Weights : 39.50, 16.40, Epoch : 423
# Loss : 49.19, Weights : 39.51, 16.41, Epoch : 424
# Loss : 49.18, Weights : 39.51, 16.41, Epoch : 425
# Loss : 49.18, Weights : 39.52, 16.41, Epoch : 426
# Loss : 49.18, Weights : 39.52, 16.41, Epoch : 427
# Loss : 49.17, Weights : 39.53, 16.41, Epoch : 428
# Loss : 49.17, Weights : 39.53, 16.42, Epoch : 429
# Loss : 49.17, Weights : 39.54, 16.42, Epoch : 430
# Loss : 49.16, Weights : 39.54, 16.42, Epoch : 431
# Loss : 49.16, Weights : 39.55, 16.42, Epoch : 432
# Loss : 49.16, Weights : 39.55, 16.43, Epoch : 433
# Loss : 49.15, Weights : 39.56, 16.43, Epoch : 434
# Loss : 49.15, Weights : 39.56, 16.43, Epoch : 435
# Loss : 49.15, Weights : 39.57, 16.43, Epoch : 436
# Loss : 49.14, Weights : 39.57, 16.43, Epoch : 437
# Loss : 49.14, Weights : 39.58, 16.44, Epoch : 438
# Loss : 49.14, Weights : 39.58, 16.44, Epoch : 439
# Loss : 49.14, Weights : 39.59, 16.44, Epoch : 440
# Loss : 49.13, Weights : 39.59, 16.44, Epoch : 441
# Loss : 49.13, Weights : 39.60, 16.44, Epoch : 442
# Loss : 49.13, Weights : 39.60, 16.45, Epoch : 443
# Loss : 49.13, Weights : 39.60, 16.45, Epoch : 444
# Loss : 49.12, Weights : 39.61, 16.45, Epoch : 445
# Loss : 49.12, Weights : 39.61, 16.45, Epoch : 446
# Loss : 49.12, Weights : 39.62, 16.45, Epoch : 447
# Loss : 49.12, Weights : 39.62, 16.45, Epoch : 448
# Loss : 49.12, Weights : 39.63, 16.46, Epoch : 449
# Loss : 49.11, Weights : 39.63, 16.46, Epoch : 450
# Loss : 49.11, Weights : 39.63, 16.46, Epoch : 451
# Loss : 49.11, Weights : 39.64, 16.46, Epoch : 452
# Loss : 49.11, Weights : 39.64, 16.46, Epoch : 453
# Loss : 49.11, Weights : 39.65, 16.47, Epoch : 454
# Loss : 49.10, Weights : 39.65, 16.47, Epoch : 455
# Loss : 49.10, Weights : 39.65, 16.47, Epoch : 456
# Loss : 49.10, Weights : 39.66, 16.47, Epoch : 457
# Loss : 49.10, Weights : 39.66, 16.47, Epoch : 458
# Loss : 49.10, Weights : 39.67, 16.47, Epoch : 459
# Loss : 49.09, Weights : 39.67, 16.48, Epoch : 460
# Loss : 49.09, Weights : 39.67, 16.48, Epoch : 461
# Loss : 49.09, Weights : 39.68, 16.48, Epoch : 462
# Loss : 49.09, Weights : 39.68, 16.48, Epoch : 463
# Loss : 49.09, Weights : 39.69, 16.48, Epoch : 464
# Loss : 49.09, Weights : 39.69, 16.48, Epoch : 465
# Loss : 49.08, Weights : 39.69, 16.48, Epoch : 466
# Loss : 49.08, Weights : 39.70, 16.49, Epoch : 467
# Loss : 49.08, Weights : 39.70, 16.49, Epoch : 468
# Loss : 49.08, Weights : 39.70, 16.49, Epoch : 469
# Loss : 49.08, Weights : 39.71, 16.49, Epoch : 470
# Loss : 49.08, Weights : 39.71, 16.49, Epoch : 471
# Loss : 49.08, Weights : 39.71, 16.49, Epoch : 472
# Loss : 49.07, Weights : 39.72, 16.49, Epoch : 473
# Loss : 49.07, Weights : 39.72, 16.50, Epoch : 474
# Loss : 49.07, Weights : 39.72, 16.50, Epoch : 475
# Loss : 49.07, Weights : 39.73, 16.50, Epoch : 476
# Loss : 49.07, Weights : 39.73, 16.50, Epoch : 477
# Loss : 49.07, Weights : 39.73, 16.50, Epoch : 478
# Loss : 49.07, Weights : 39.74, 16.50, Epoch : 479
# Loss : 49.07, Weights : 39.74, 16.50, Epoch : 480
# Loss : 49.06, Weights : 39.74, 16.51, Epoch : 481
# Loss : 49.06, Weights : 39.75, 16.51, Epoch : 482
# Loss : 49.06, Weights : 39.75, 16.51, Epoch : 483
# Loss : 49.06, Weights : 39.75, 16.51, Epoch : 484
# Loss : 49.06, Weights : 39.75, 16.51, Epoch : 485
# Loss : 49.06, Weights : 39.76, 16.51, Epoch : 486
# Loss : 49.06, Weights : 39.76, 16.51, Epoch : 487
# Loss : 49.06, Weights : 39.76, 16.51, Epoch : 488
# Loss : 49.06, Weights : 39.77, 16.52, Epoch : 489
# Loss : 49.06, Weights : 39.77, 16.52, Epoch : 490
# Loss : 49.05, Weights : 39.77, 16.52, Epoch : 491
# Loss : 49.05, Weights : 39.77, 16.52, Epoch : 492
# Loss : 49.05, Weights : 39.78, 16.52, Epoch : 493
# Loss : 49.05, Weights : 39.78, 16.52, Epoch : 494
# Loss : 49.05, Weights : 39.78, 16.52, Epoch : 495
# Loss : 49.05, Weights : 39.78, 16.52, Epoch : 496
# Loss : 49.05, Weights : 39.79, 16.52, Epoch : 497
# Loss : 49.05, Weights : 39.79, 16.53, Epoch : 498
# Loss : 49.05, Weights : 39.79, 16.53, Epoch : 499
# Loss : 49.05, Weights : 39.80, 16.53, Epoch : 500
# Loss : 49.05, Weights : 39.80, 16.53, Epoch : 501
# Loss : 49.05, Weights : 39.80, 16.53, Epoch : 502
# Loss : 49.04, Weights : 39.80, 16.53, Epoch : 503
# Loss : 49.04, Weights : 39.81, 16.53, Epoch : 504
# Loss : 49.04, Weights : 39.81, 16.53, Epoch : 505
# Loss : 49.04, Weights : 39.81, 16.53, Epoch : 506
# Loss : 49.04, Weights : 39.81, 16.53, Epoch : 507
# Loss : 49.04, Weights : 39.81, 16.54, Epoch : 508
# Loss : 49.04, Weights : 39.82, 16.54, Epoch : 509
# Loss : 49.04, Weights : 39.82, 16.54, Epoch : 510
# Loss : 49.04, Weights : 39.82, 16.54, Epoch : 511
# Loss : 49.04, Weights : 39.82, 16.54, Epoch : 512
# Loss : 49.04, Weights : 39.83, 16.54, Epoch : 513
# Loss : 49.04, Weights : 39.83, 16.54, Epoch : 514
# Loss : 49.04, Weights : 39.83, 16.54, Epoch : 515
# Loss : 49.04, Weights : 39.83, 16.54, Epoch : 516
# Loss : 49.04, Weights : 39.83, 16.54, Epoch : 517
# Loss : 49.04, Weights : 39.84, 16.55, Epoch : 518
# Loss : 49.03, Weights : 39.84, 16.55, Epoch : 519
# Loss : 49.03, Weights : 39.84, 16.55, Epoch : 520
# Loss : 49.03, Weights : 39.84, 16.55, Epoch : 521
# Loss : 49.03, Weights : 39.85, 16.55, Epoch : 522
# Loss : 49.03, Weights : 39.85, 16.55, Epoch : 523
# Loss : 49.03, Weights : 39.85, 16.55, Epoch : 524
# Loss : 49.03, Weights : 39.85, 16.55, Epoch : 525
# Loss : 49.03, Weights : 39.85, 16.55, Epoch : 526
# Loss : 49.03, Weights : 39.86, 16.55, Epoch : 527
# Loss : 49.03, Weights : 39.86, 16.55, Epoch : 528
# Loss : 49.03, Weights : 39.86, 16.55, Epoch : 529
# Loss : 49.03, Weights : 39.86, 16.56, Epoch : 530
# Loss : 49.03, Weights : 39.86, 16.56, Epoch : 531
# Loss : 49.03, Weights : 39.86, 16.56, Epoch : 532
# Loss : 49.03, Weights : 39.87, 16.56, Epoch : 533
# Loss : 49.03, Weights : 39.87, 16.56, Epoch : 534
# Loss : 49.03, Weights : 39.87, 16.56, Epoch : 535
# Loss : 49.03, Weights : 39.87, 16.56, Epoch : 536
# Loss : 49.03, Weights : 39.87, 16.56, Epoch : 537
# Loss : 49.03, Weights : 39.88, 16.56, Epoch : 538
# Loss : 49.03, Weights : 39.88, 16.56, Epoch : 539
# Loss : 49.03, Weights : 39.88, 16.56, Epoch : 540
# Loss : 49.03, Weights : 39.88, 16.56, Epoch : 541
# Loss : 49.03, Weights : 39.88, 16.56, Epoch : 542
# Loss : 49.02, Weights : 39.88, 16.56, Epoch : 543
# Loss : 49.02, Weights : 39.89, 16.57, Epoch : 544
# Loss : 49.02, Weights : 39.89, 16.57, Epoch : 545
# Loss : 49.02, Weights : 39.89, 16.57, Epoch : 546
# Loss : 49.02, Weights : 39.89, 16.57, Epoch : 547
# Loss : 49.02, Weights : 39.89, 16.57, Epoch : 548
# Loss : 49.02, Weights : 39.89, 16.57, Epoch : 549
# Loss : 49.02, Weights : 39.89, 16.57, Epoch : 550
# Loss : 49.02, Weights : 39.90, 16.57, Epoch : 551
# Loss : 49.02, Weights : 39.90, 16.57, Epoch : 552
# Loss : 49.02, Weights : 39.90, 16.57, Epoch : 553
# Loss : 49.02, Weights : 39.90, 16.57, Epoch : 554
# Loss : 49.02, Weights : 39.90, 16.57, Epoch : 555
# Loss : 49.02, Weights : 39.90, 16.57, Epoch : 556
# Loss : 49.02, Weights : 39.90, 16.57, Epoch : 557
# Loss : 49.02, Weights : 39.91, 16.57, Epoch : 558
# Loss : 49.02, Weights : 39.91, 16.58, Epoch : 559
# Loss : 49.02, Weights : 39.91, 16.58, Epoch : 560
# Loss : 49.02, Weights : 39.91, 16.58, Epoch : 561
# Loss : 49.02, Weights : 39.91, 16.58, Epoch : 562
# Loss : 49.02, Weights : 39.91, 16.58, Epoch : 563
# Loss : 49.02, Weights : 39.91, 16.58, Epoch : 564
# Loss : 49.02, Weights : 39.92, 16.58, Epoch : 565
# Loss : 49.02, Weights : 39.92, 16.58, Epoch : 566
# Loss : 49.02, Weights : 39.92, 16.58, Epoch : 567
# Loss : 49.02, Weights : 39.92, 16.58, Epoch : 568
# Loss : 49.02, Weights : 39.92, 16.58, Epoch : 569
# Loss : 49.02, Weights : 39.92, 16.58, Epoch : 570
# Loss : 49.02, Weights : 39.92, 16.58, Epoch : 571
# Loss : 49.02, Weights : 39.92, 16.58, Epoch : 572
# Loss : 49.02, Weights : 39.93, 16.58, Epoch : 573
# Loss : 49.02, Weights : 39.93, 16.58, Epoch : 574
# Loss : 49.02, Weights : 39.93, 16.58, Epoch : 575
# Loss : 49.02, Weights : 39.93, 16.58, Epoch : 576
# Loss : 49.02, Weights : 39.93, 16.58, Epoch : 577
# Loss : 49.02, Weights : 39.93, 16.59, Epoch : 578
# Loss : 49.02, Weights : 39.93, 16.59, Epoch : 579
# Loss : 49.02, Weights : 39.93, 16.59, Epoch : 580
# Loss : 49.02, Weights : 39.94, 16.59, Epoch : 581
# Loss : 49.02, Weights : 39.94, 16.59, Epoch : 582
# Loss : 49.02, Weights : 39.94, 16.59, Epoch : 583
# Loss : 49.02, Weights : 39.94, 16.59, Epoch : 584
# Loss : 49.02, Weights : 39.94, 16.59, Epoch : 585
# Loss : 49.02, Weights : 39.94, 16.59, Epoch : 586
# Loss : 49.02, Weights : 39.94, 16.59, Epoch : 587
# Loss : 49.02, Weights : 39.94, 16.59, Epoch : 588
# Loss : 49.02, Weights : 39.94, 16.59, Epoch : 589
# Loss : 49.02, Weights : 39.94, 16.59, Epoch : 590
# Loss : 49.02, Weights : 39.95, 16.59, Epoch : 591
# Loss : 49.01, Weights : 39.95, 16.59, Epoch : 592
# Loss : 49.01, Weights : 39.95, 16.59, Epoch : 593
# Loss : 49.01, Weights : 39.95, 16.59, Epoch : 594
# Loss : 49.01, Weights : 39.95, 16.59, Epoch : 595
# Loss : 49.01, Weights : 39.95, 16.59, Epoch : 596
# Loss : 49.01, Weights : 39.95, 16.59, Epoch : 597
# Loss : 49.01, Weights : 39.95, 16.59, Epoch : 598
# Loss : 49.01, Weights : 39.95, 16.59, Epoch : 599
# Loss : 49.01, Weights : 39.95, 16.59, Epoch : 600
# Loss : 49.01, Weights : 39.96, 16.60, Epoch : 601
# Loss : 49.01, Weights : 39.96, 16.60, Epoch : 602
# Loss : 49.01, Weights : 39.96, 16.60, Epoch : 603
# Loss : 49.01, Weights : 39.96, 16.60, Epoch : 604
# Loss : 49.01, Weights : 39.96, 16.60, Epoch : 605
# Loss : 49.01, Weights : 39.96, 16.60, Epoch : 606
# Loss : 49.01, Weights : 39.96, 16.60, Epoch : 607
# Loss : 49.01, Weights : 39.96, 16.60, Epoch : 608
# Loss : 49.01, Weights : 39.96, 16.60, Epoch : 609
# Loss : 49.01, Weights : 39.96, 16.60, Epoch : 610
# Loss : 49.01, Weights : 39.96, 16.60, Epoch : 611
# Loss : 49.01, Weights : 39.96, 16.60, Epoch : 612
# Loss : 49.01, Weights : 39.97, 16.60, Epoch : 613
# Loss : 49.01, Weights : 39.97, 16.60, Epoch : 614
# Loss : 49.01, Weights : 39.97, 16.60, Epoch : 615
# Loss : 49.01, Weights : 39.97, 16.60, Epoch : 616
# Loss : 49.01, Weights : 39.97, 16.60, Epoch : 617
# Loss : 49.01, Weights : 39.97, 16.60, Epoch : 618
# Loss : 49.01, Weights : 39.97, 16.60, Epoch : 619
# Loss : 49.01, Weights : 39.97, 16.60, Epoch : 620
# Loss : 49.01, Weights : 39.97, 16.60, Epoch : 621
# Loss : 49.01, Weights : 39.97, 16.60, Epoch : 622
# Loss : 49.01, Weights : 39.97, 16.60, Epoch : 623
# Loss : 49.01, Weights : 39.97, 16.60, Epoch : 624
# Loss : 49.01, Weights : 39.97, 16.60, Epoch : 625
# Loss : 49.01, Weights : 39.98, 16.60, Epoch : 626
# Loss : 49.01, Weights : 39.98, 16.60, Epoch : 627
# Loss : 49.01, Weights : 39.98, 16.60, Epoch : 628
# Loss : 49.01, Weights : 39.98, 16.60, Epoch : 629
# Loss : 49.01, Weights : 39.98, 16.61, Epoch : 630
# Loss : 49.01, Weights : 39.98, 16.61, Epoch : 631
# Loss : 49.01, Weights : 39.98, 16.61, Epoch : 632
# Loss : 49.01, Weights : 39.98, 16.61, Epoch : 633
# Loss : 49.01, Weights : 39.98, 16.61, Epoch : 634
# Loss : 49.01, Weights : 39.98, 16.61, Epoch : 635
# Loss : 49.01, Weights : 39.98, 16.61, Epoch : 636
# Loss : 49.01, Weights : 39.98, 16.61, Epoch : 637
# Loss : 49.01, Weights : 39.98, 16.61, Epoch : 638
# Loss : 49.01, Weights : 39.98, 16.61, Epoch : 639
# Loss : 49.01, Weights : 39.98, 16.61, Epoch : 640
# Loss : 49.01, Weights : 39.99, 16.61, Epoch : 641
# Loss : 49.01, Weights : 39.99, 16.61, Epoch : 642
# Loss : 49.01, Weights : 39.99, 16.61, Epoch : 643
# Loss : 49.01, Weights : 39.99, 16.61, Epoch : 644
# Loss : 49.01, Weights : 39.99, 16.61, Epoch : 645
# Loss : 49.01, Weights : 39.99, 16.61, Epoch : 646
# Loss : 49.01, Weights : 39.99, 16.61, Epoch : 647
# Loss : 49.01, Weights : 39.99, 16.61, Epoch : 648
# Loss : 49.01, Weights : 39.99, 16.61, Epoch : 649
# Loss : 49.01, Weights : 39.99, 16.61, Epoch : 650
# Loss : 49.01, Weights : 39.99, 16.61, Epoch : 651
# Loss : 49.01, Weights : 39.99, 16.61, Epoch : 652
# Loss : 49.01, Weights : 39.99, 16.61, Epoch : 653
# Loss : 49.01, Weights : 39.99, 16.61, Epoch : 654
# Loss : 49.01, Weights : 39.99, 16.61, Epoch : 655
# Loss : 49.01, Weights : 39.99, 16.61, Epoch : 656
# Loss : 49.01, Weights : 39.99, 16.61, Epoch : 657
# Loss : 49.01, Weights : 39.99, 16.61, Epoch : 658
# Loss : 49.01, Weights : 40.00, 16.61, Epoch : 659
# Loss : 49.01, Weights : 40.00, 16.61, Epoch : 660
# Loss : 49.01, Weights : 40.00, 16.61, Epoch : 661
# Loss : 49.01, Weights : 40.00, 16.61, Epoch : 662
# Loss : 49.01, Weights : 40.00, 16.61, Epoch : 663
# Loss : 49.01, Weights : 40.00, 16.61, Epoch : 664
# Loss : 49.01, Weights : 40.00, 16.61, Epoch : 665
# Loss : 49.01, Weights : 40.00, 16.61, Epoch : 666
# Loss : 49.01, Weights : 40.00, 16.61, Epoch : 667
# Loss : 49.01, Weights : 40.00, 16.61, Epoch : 668
# Loss : 49.01, Weights : 40.00, 16.61, Epoch : 669
# Loss : 49.01, Weights : 40.00, 16.61, Epoch : 670
# Loss : 49.01, Weights : 40.00, 16.61, Epoch : 671
# Loss : 49.01, Weights : 40.00, 16.61, Epoch : 672
# Loss : 49.01, Weights : 40.00, 16.62, Epoch : 673
# Loss : 49.01, Weights : 40.00, 16.62, Epoch : 674
# Loss : 49.01, Weights : 40.00, 16.62, Epoch : 675
# Loss : 49.01, Weights : 40.00, 16.62, Epoch : 676
# Loss : 49.01, Weights : 40.00, 16.62, Epoch : 677
# Loss : 49.01, Weights : 40.00, 16.62, Epoch : 678
# Loss : 49.01, Weights : 40.00, 16.62, Epoch : 679
# Loss : 49.01, Weights : 40.00, 16.62, Epoch : 680
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 681
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 682
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 683
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 684
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 685
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 686
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 687
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 688
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 689
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 690
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 691
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 692
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 693
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 694
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 695
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 696
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 697
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 698
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 699
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 700
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 701
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 702
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 703
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 704
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 705
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 706
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 707
# Loss : 49.01, Weights : 40.01, 16.62, Epoch : 708
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 709
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 710
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 711
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 712
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 713
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 714
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 715
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 716
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 717
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 718
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 719
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 720
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 721
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 722
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 723
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 724
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 725
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 726
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 727
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 728
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 729
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 730
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 731
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 732
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 733
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 734
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 735
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 736
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 737
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 738
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 739
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 740
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 741
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 742
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 743
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 744
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 745
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 746
# Loss : 49.01, Weights : 40.02, 16.62, Epoch : 747
# Loss : 49.01, Weights : 40.03, 16.62, Epoch : 748
# Loss : 49.01, Weights : 40.03, 16.62, Epoch : 749
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 750
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 751
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 752
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 753
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 754
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 755
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 756
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 757
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 758
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 759
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 760
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 761
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 762
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 763
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 764
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 765
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 766
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 767
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 768
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 769
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 770
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 771
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 772
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 773
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 774
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 775
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 776
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 777
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 778
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 779
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 780
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 781
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 782
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 783
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 784
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 785
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 786
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 787
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 788
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 789
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 790
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 791
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 792
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 793
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 794
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 795
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 796
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 797
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 798
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 799
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 800
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 801
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 802
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 803
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 804
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 805
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 806
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 807
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 808
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 809
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 810
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 811
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 812
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 813
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 814
# Loss : 49.01, Weights : 40.03, 16.63, Epoch : 815
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 816
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 817
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 818
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 819
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 820
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 821
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 822
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 823
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 824
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 825
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 826
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 827
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 828
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 829
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 830
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 831
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 832
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 833
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 834
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 835
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 836
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 837
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 838
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 839
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 840
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 841
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 842
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 843
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 844
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 845
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 846
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 847
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 848
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 849
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 850
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 851
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 852
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 853
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 854
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 855
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 856
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 857
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 858
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 859
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 860
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 861
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 862
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 863
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 864
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 865
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 866
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 867
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 868
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 869
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 870
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 871
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 872
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 873
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 874
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 875
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 876
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 877
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 878
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 879
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 880
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 881
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 882
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 883
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 884
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 885
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 886
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 887
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 888
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 889
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 890
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 891
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 892
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 893
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 894
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 895
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 896
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 897
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 898
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 899
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 900
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 901
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 902
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 903
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 904
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 905
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 906
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 907
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 908
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 909
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 910
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 911
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 912
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 913
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 914
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 915
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 916
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 917
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 918
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 919
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 920
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 921
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 922
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 923
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 924
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 925
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 926
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 927
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 928
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 929
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 930
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 931
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 932
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 933
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 934
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 935
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 936
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 937
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 938
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 939
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 940
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 941
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 942
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 943
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 944
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 945
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 946
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 947
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 948
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 949
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 950
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 951
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 952
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 953
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 954
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 955
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 956
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 957
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 958
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 959
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 960
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 961
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 962
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 963
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 964
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 965
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 966
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 967
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 968
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 969
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 970
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 971
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 972
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 973
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 974
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 975
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 976
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 977
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 978
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 979
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 980
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 981
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 982
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 983
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 984
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 985
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 986
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 987
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 988
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 989
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 990
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 991
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 992
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 993
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 994
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 995
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 996
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 997
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 998
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 999
# Loss : 49.01, Weights : 40.04, 16.63, Epoch : 1000
# [np.float64(40.04368656388044), np.float64(16.632862768951316)]

# %%
ypred = W_new[1] * np.linspace(-4, 4, 1000) + W_new[0]



plt.figure(figsize=(10, 8))
plt.scatter(X, Y, c=Y, cmap=plt.cm.coolwarm, label="Data Points")
plt.axhline(y=0, color='black', linewidth=1)  # X-axis line
plt.axvline(x=0, color='black', linewidth=1)  # Y-axis line
plt.title("Linear Regression", fontsize=16, weight="bold")
plt.plot(np.linspace(-4, 4, 1000), ypred, c="darkviolet", label="Linear Regression Line")
plt.xlabel("X axis", fontsize=12, weight="bold")
plt.ylabel("Y axis", fontsize=12, weight="bold")
plt.legend()
plt.grid(linestyle="--", alpha=0.8)
plt.show()

plt.figure(figsize=(10, 8))
plt.title("Loss Of Linear Regression", fontsize=16, weight="bold")
plt.plot(np.linspace(1, epochs, epochs+1), np.array(losses), c="darkviolet", label="Linear Regression Line")
plt.xlabel("Epochs", fontsize=12, weight="bold")
plt.ylabel("Loss Value", fontsize=12, weight="bold")
plt.legend()
plt.grid(linestyle="--", alpha=0.8)
plt.show()

# %% [markdown]
# ### Checking The Scratch Model With Scikit-Learn Library Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

x_reg_line = np.linspace(-4, 4, 1000)

standardscaler = StandardScaler()

x_scaled = standardscaler.fit_transform(X)

reg_model = LinearRegression()

reg_model.fit(X, Y)

y_pred_model = reg_model.coef_[0] * x_reg_line + reg_model.intercept_

print(f"Weights : {reg_model.coef_[0]}, {reg_model.intercept_}")
# Out:
# Weights : 16.633546051995488, 40.04526205905821

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming W_new and losses are already defined
x_vals = np.linspace(-4, 4, 1000)
ypred = W_new[1] * x_vals + W_new[0]

fig, axs = plt.subplots(1, 2, figsize=(16, 8), dpi=100)  # 2 rows, 1 column

# --- Plot 1: Regression Line ---
axs[0].scatter(X, Y, c=Y, cmap=plt.cm.coolwarm, label="Data Points")
axs[0].plot(x_vals, ypred, c="darkviolet", label=f"Linear Regression Line, Weights = {W_new[1]:.2f}, {W_new[0]:.2f}")
axs[0].plot(x_vals, y_pred_model, c="#16163b", label=f"Linear Regression Model, Weights = {reg_model.coef_[0]:.2f}, {reg_model.intercept_:.2f}")
axs[0].axhline(y=0, color='black', linewidth=1)
axs[0].axvline(x=0, color='black', linewidth=1)
axs[0].set_title("Linear Regression", fontsize=16, weight="bold")
axs[0].set_xlabel("X axis", fontsize=12, weight="bold")
axs[0].set_ylabel("Y axis", fontsize=12, weight="bold")
axs[0].legend()
axs[0].grid(linestyle="--", alpha=0.8)

# --- Plot 2: Loss Curve ---
axs[1].plot(np.linspace(1, len(losses), len(losses)), np.array(losses), c="darkblue", label=f"Loss Curve\nObserved Loss = {losses[-1]:.2f}")
axs[1].axhline(y=0, color='black', linewidth=1)
axs[1].axvline(x=0, color='black', linewidth=1)
axs[1].set_title("Loss of Linear Regression", fontsize=16, weight="bold")
axs[1].set_xlabel("Epochs", fontsize=12, weight="bold")
axs[1].set_ylabel("\n\nLoss", fontsize=12, weight="bold")
axs[1].legend()
axs[1].grid(linestyle="--", alpha=0.8)

plt.tight_layout()
plt.show()
plt.savefig("Linear.png")
